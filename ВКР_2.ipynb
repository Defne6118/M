# %% [markdown]
# <a href="https://colab.research.google.com/github/Defne6118/M/blob/main/%D0%92%D0%9A%D0%A0_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.preprocessing import LabelEncoder

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/Дипломный проект
X_bp = pd.read_excel("X_bp.xlsx")
X_bp.set_index('Unnamed: 0',inplace=True)
X_bp.head(5)
# Out:
# /content/gdrive/MyDrive/Дипломный проект
#             Соотношение матрица-наполнитель  Плотность, кг/м3  \
# Unnamed: 0
# 0                                  1.857143            2030.0
# 1                                  1.857143            2030.0
# 2                                  1.857143            2030.0
# 3                                  1.857143            2030.0
# 4                                  2.771331            2030.0
#
#             модуль упругости, ГПа  Количество отвердителя, м.%  \
# Unnamed: 0
# 0                      738.736842                        30.00
# 1                      738.736842                        50.00
# 2                      738.736842                        49.90
# 3                      738.736842                       129.00
# 4                      753.000000                       111.86
#
#             Содержание эпоксидных групп,%_2  Температура вспышки, С_2  \
# Unnamed: 0
# ...

# %%
X_nup = pd.read_excel("X_nup.xlsx")
X_nup.set_index('Unnamed: 0',inplace=True)
X_nup.head(5)
# Out:
#             Угол нашивки, град  Шаг нашивки  Плотность нашивки
# Unnamed: 0
# 0                            0          4.0               57.0
# 1                            0          4.0               60.0
# 2                            0          4.0               70.0
# 3                            0          5.0               47.0
# 4                            0          5.0               57.0

# %%
df=X_bp.join(X_nup, how = 'inner')
df.head()
# Out:
#             Соотношение матрица-наполнитель  Плотность, кг/м3  \
# Unnamed: 0
# 0                                  1.857143            2030.0
# 1                                  1.857143            2030.0
# 2                                  1.857143            2030.0
# 3                                  1.857143            2030.0
# 4                                  2.771331            2030.0
#
#             модуль упругости, ГПа  Количество отвердителя, м.%  \
# Unnamed: 0
# 0                      738.736842                        30.00
# 1                      738.736842                        50.00
# 2                      738.736842                        49.90
# 3                      738.736842                       129.00
# 4                      753.000000                       111.86
#
#             Содержание эпоксидных групп,%_2  Температура вспышки, С_2  \
# Unnamed: 0
# 0                                 22.267857                100.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1023 entries, 0 to 1022
# Data columns (total 13 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Соотношение матрица-наполнитель       1023 non-null   float64
#  1   Плотность, кг/м3                      1023 non-null   float64
#  2   модуль упругости, ГПа                 1023 non-null   float64
#  3   Количество отвердителя, м.%           1023 non-null   float64
#  4   Содержание эпоксидных групп,%_2       1023 non-null   float64
#  5   Температура вспышки, С_2              1023 non-null   float64
#  6   Поверхностная плотность, г/м2         1023 non-null   float64
#  7   Модуль упругости при растяжении, ГПа  1023 non-null   float64
#  8   Прочность при растяжении, МПа         1023 non-null   float64
#  9   Потребление смолы, г/м2               1023 non-null   float64
# ...

# %%
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %% [markdown]
# *1*. Разведочный анализ данных

# %%
sns.histplot(df['Плотность, кг/м3'], kde=False, bins=30, color='blue')

# %%
sns.histplot(df['модуль упругости, ГПа'], kde=True, bins=30, color='red')

# %%
sns.histplot(df['Количество отвердителя, м.%'], kde=False, bins=30, color='yellow')

# %%
sns.histplot(df['Содержание эпоксидных групп,%_2'], kde=False, bins=30, color='green')

# %%
sns.histplot(df['Температура вспышки, С_2'], kde=False, bins=30, color='pink')

# %%
sns.histplot(df['Поверхностная плотность, г/м2'], kde=False, bins=30, color='indigo')

# %%
sns.histplot(df['Модуль упругости при растяжении, ГПа'], kde=False, bins=30, color='plum')

# %%
sns.histplot(df['Прочность при растяжении, МПа'], kde=False, bins=30, color='brown')

# %%
sns.histplot(df['Потребление смолы, г/м2'], kde=False, bins=30, color='teal')

# %%
sns.histplot(df['Угол нашивки, град'], kde=False, bins=30, color='azure')

# %%
sns.histplot(df['Шаг нашивки'], kde=False, bins=50, color='magenta')

# %%
sns.histplot(df['Плотность нашивки'], kde=False, bins=50, color='aquamarine')

# %% [markdown]
# Ящик с усами

# %%
sns.boxplot(data=df, palette='pastel', x='Угол нашивки, град', y='Плотность, кг/м3')

# %%
sns.boxplot(data=df, palette='colorblind', x='Угол нашивки, град', y='модуль упругости, ГПа')

# %%
sns.boxplot(data=df, palette='deep', x='Угол нашивки, град', y='Количество отвердителя, м.%')

# %%
sns.boxplot(data=df, palette='deep', x='Угол нашивки, град', y='Содержание эпоксидных групп,%_2')

# %%
sns.boxplot(data=df, palette='deep', x='Угол нашивки, град', y='Температура вспышки, С_2')

# %%
sns.boxplot(data=df, palette='deep', x='Угол нашивки, град', y='Поверхностная плотность, г/м2')

# %%
sns.boxplot(data=df, palette='deep', x='Угол нашивки, град', y='Модуль упругости при растяжении, ГПа')

# %%
sns.boxplot(data=df, palette='deep', x='Угол нашивки, град', y='Прочность при растяжении, МПа')

# %%
sns.boxplot(data=df, palette='muted', x='Угол нашивки, град', y='Потребление смолы, г/м2')

# %%
sns.boxplot(data=df, palette='pastel', x='Угол нашивки, град', y='Шаг нашивки')

# %%
sns.boxplot(data=df, palette='pastel', x='Угол нашивки, град', y='Плотность нашивки')

# %% [markdown]
# Попарные графики рассеяния точек

# %%
sns.pairplot(data=df[df['Угол нашивки, град']==0], hue='Угол нашивки, град', palette='Blues_r')

# %%
sns.pairplot(data=df[df['Угол нашивки, град']==90], hue='Угол нашивки, град', palette='Purples_r')

# %% [markdown]
# Коэффициент корреляции

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.heatmap(df.corr(), annot=True, fmt='.1g', cmap='viridis', linewidths=1, linecolor='black')

# %%
df.describe()
# Out:
#        Соотношение матрица-наполнитель  Плотность, кг/м3  \
# count                      1023.000000       1023.000000
# mean                          2.930366       1975.734888
# std                           0.913222         73.729231
# min                           0.389403       1731.764635
# 25%                           2.317887       1924.155466
# 50%                           2.906878       1977.621657
# 75%                           3.552660       2021.374375
# max                           5.591742       2207.773481
#
#        модуль упругости, ГПа  Количество отвердителя, м.%  \
# count            1023.000000                  1023.000000
# mean              739.923233                   110.570769
# std               330.231581                    28.295911
# min                 2.436909                    17.740275
# 25%               500.047452                    92.443497
# 50%               739.664328                   110.564840
# ...

# %%
le=LabelEncoder()
df['Угол нашивки, град']=le.fit_transform(df['Угол нашивки, град'])
df
# Out:
#             Соотношение матрица-наполнитель  Плотность, кг/м3  \
# Unnamed: 0
# 0                                  1.857143       2030.000000
# 1                                  1.857143       2030.000000
# 2                                  1.857143       2030.000000
# 3                                  1.857143       2030.000000
# 4                                  2.771331       2030.000000
# ...                                     ...               ...
# 1018                               2.271346       1952.087902
# 1019                               3.444022       2050.089171
# 1020                               3.280604       1972.372865
# 1021                               3.705351       2066.799773
# 1022                               3.808020       1890.413468
#
#             модуль упругости, ГПа  Количество отвердителя, м.%  \
# Unnamed: 0
# 0                      738.736842                    30.000000
# 1                      738.736842                    50.000000
# ...

# %% [markdown]
# *Удаление* выбросов

# %%
for column in df[df['Угол нашивки, град']==0].columns:
  q75, q25=np.percentile(df.loc[:, column],[75,25])
  intr_qr=q75-q25
  max=q75+(1.5*intr_qr)
  min=q25-(1.5*intr_qr)
  df.loc[df[column]<min,column]=np.nan
  df.loc[df[column]>max,column]=np.nan

# %%
 for column in df[df['Угол нашивки, град']==1].columns:
  q75, q25=np.percentile(df.loc[:, column],[75,25])
  intr_qr=q75-q25
  max=q75+(1.5*intr_qr)
  min=q25-(1.5*intr_qr)
  df.loc[df[column]<min,column]=np.nan
  df.loc[df[column]>max,column]=np.nan

# %% [markdown]
#  Нулевые значения в каждом столбце

# %%
# Evaluating for Missing Data
missing_data = df.isnull()
missing_data.head(6)
# Out:
#             Соотношение матрица-наполнитель  Плотность, кг/м3  \
# Unnamed: 0
# 0                                     False             False
# 1                                     False             False
# 2                                     False             False
# 3                                     False             False
# 4                                     False             False
# 5                                     False             False
#
#             модуль упругости, ГПа  Количество отвердителя, м.%  \
# Unnamed: 0
# 0                           False                         True
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# 5                           False                        False
#
# ...

# %%
# Count missing values in each column
for column in missing_data.columns.values.tolist():
    print(column)
    print(missing_data[column].value_counts())
    print(" ")
# Out:
# Соотношение матрица-наполнитель
# False    1017
# True        6
# Name: Соотношение матрица-наполнитель, dtype: int64
#
# Плотность, кг/м3
# False    1014
# True        9
# Name: Плотность, кг/м3, dtype: int64
#
# модуль упругости, ГПа
# False    1021
# True        2
# Name: модуль упругости, ГПа, dtype: int64
#
# Количество отвердителя, м.%
# False    1009
# True       14
# Name: Количество отвердителя, м.%, dtype: int64
#
# Содержание эпоксидных групп,%_2
# False    1021
# True        2
# Name: Содержание эпоксидных групп,%_2, dtype: int64
#
# Температура вспышки, С_2
# False    1015
# True        8
# Name: Температура вспышки, С_2, dtype: int64
#
# Поверхностная плотность, г/м2
# False    1021
# True        2
# Name: Поверхностная плотность, г/м2, dtype: int64
#
# Модуль упругости при растяжении, ГПа
# False    1017
# True        6
# Name: Модуль упругости при растяжении, ГПа, dtype: int64
#
# Прочность при растяжении, МПа
# False    1012
# True       11
# ...

# %%
#пропущенные значения в каждой колонке
df.isnull().sum()
# Out:
# Соотношение матрица-наполнитель          6
# Плотность, кг/м3                         9
# модуль упругости, ГПа                    2
# Количество отвердителя, м.%             14
# Содержание эпоксидных групп,%_2          2
# Температура вспышки, С_2                 8
# Поверхностная плотность, г/м2            2
# Модуль упругости при растяжении, ГПа     6
# Прочность при растяжении, МПа           11
# Потребление смолы, г/м2                  8
# Угол нашивки, град                       0
# Шаг нашивки                              4
# Плотность нашивки                       21
# dtype: int64

# %%
# Пропущенные значения заполнить средним значением
df['Соотношение матрица-наполнитель'].fillna(df['Соотношение матрица-наполнитель'].mean(), inplace = True)
df['Плотность, кг/м3'].fillna(df['Плотность, кг/м3'].mean(), inplace = True)
df['модуль упругости, ГПа'].fillna(df['модуль упругости, ГПа'].mean(), inplace = True)
df['Количество отвердителя, м.%'].fillna(df['Количество отвердителя, м.%'].mean(), inplace = True)
df['Содержание эпоксидных групп,%_2'].fillna(df['Содержание эпоксидных групп,%_2'].mean(), inplace = True)
df['Температура вспышки, С_2'].fillna(df['Температура вспышки, С_2'].mean(), inplace = True)
df['Поверхностная плотность, г/м2'].fillna(df['Поверхностная плотность, г/м2'].mean(), inplace = True)
df['Модуль упругости при растяжении, ГПа'].fillna(df['Модуль упругости при растяжении, ГПа'].mean(), inplace = True)
df['Прочность при растяжении, МПа'].fillna(df['Прочность при растяжении, МПа'].mean(), inplace = True)
df['Потребление смолы, г/м2'].fillna(df['Потребление смолы, г/м2'].mean(), inplace = True)
df['Шаг нашивки'].fillna(df['Шаг нашивки'].mean(), inplace = True)
df['Плотность нашивки'].fillna(df['Плотность нашивки'].mean(), inplace = True)

df.isnull().sum()
# Out:
# Соотношение матрица-наполнитель         0
# Плотность, кг/м3                        0
# модуль упругости, ГПа                   0
# Количество отвердителя, м.%             0
# Содержание эпоксидных групп,%_2         0
# Температура вспышки, С_2                0
# Поверхностная плотность, г/м2           0
# Модуль упругости при растяжении, ГПа    0
# Прочность при растяжении, МПа           0
# Потребление смолы, г/м2                 0
# Угол нашивки, град                      0
# Шаг нашивки                             0
# Плотность нашивки                       0
# dtype: int64

# %%
df.mean()
# Out:
# Соотношение матрица-наполнитель            2.925257
# Плотность, кг/м3                        1974.755152
# модуль упругости, ГПа                    737.721905
# Количество отвердителя, м.%              110.558048
# Содержание эпоксидных групп,%_2           22.241680
# Температура вспышки, С_2                 285.949508
# Поверхностная плотность, г/м2            480.944261
# Модуль упругости при растяжении, ГПа      73.311050
# Прочность при растяжении, МПа           2465.769701
# Потребление смолы, г/м2                  218.081180
# Угол нашивки, град                         0.491691
# Шаг нашивки                                6.870464
# Плотность нашивки                         57.412683
# dtype: float64

# %%
df.median()
# Out:
# Соотношение матрица-наполнитель            2.908835
# Плотность, кг/м3                        1977.112680
# модуль упругости, ГПа                    738.736842
# Количество отвердителя, м.%              110.558048
# Содержание эпоксидных групп,%_2           22.230779
# Температура вспышки, С_2                 285.949508
# Поверхностная плотность, г/м2            451.864365
# Модуль упругости при растяжении, ГПа      73.284256
# Прочность при растяжении, МПа           2462.605386
# Потребление смолы, г/м2                  218.173080
# Угол нашивки, град                         0.000000
# Шаг нашивки                                6.893973
# Плотность нашивки                         57.412683
# dtype: float64

# %% [markdown]
# 2. Провести предобработку данных (удаление шумов, нормализация и т.д.)
#
# Данные очищены от выбросов и нормализованы

# %%
from sklearn.preprocessing import MinMaxScaler
mmscaler = MinMaxScaler()
cols = ['Соотношение матрица-наполнитель', 'Плотность, кг/м3', 'модуль упругости, ГПа', 'Количество отвердителя, м.%', 'Содержание эпоксидных групп,%_2', 'Температура вспышки, С_2', 'Поверхностная плотность, г/м2', 'Модуль упругости при растяжении, ГПа', 'Прочность при растяжении, МПа', 'Потребление смолы, г/м2', 'Угол нашивки, град', 'Шаг нашивки', 'Плотность нашивки' ]
df[cols] = mmscaler.fit_transform(df[cols])
df.describe()
# Out:
#        Соотношение матрица-наполнитель  Плотность, кг/м3  \
# count                      1023.000000       1023.000000
# mean                          0.498844          0.504592
# std                           0.187191          0.187870
# min                           0.000000          0.000000
# 25%                           0.372092          0.371411
# 50%                           0.495399          0.510844
# 75%                           0.629650          0.626245
# max                           1.000000          1.000000
#
#        модуль упругости, ГПа  Количество отвердителя, м.%  \
# count            1023.000000                  1023.000000
# mean                0.446445                     0.502162
# std                 0.198214                     0.186237
# min                 0.000000                     0.000000
# 25%                 0.302135                     0.378699
# 50%                 0.447061                     0.502162
# ...

# %% [markdown]
# 3.	Обучить нескольких моделей для прогноза модуля упругости при растяжении и прочности при растяжении.
#
#  При построении модели необходимо 30% данных оставить на тестирование модели, на остальных происходит обучение моделей.
#
#  При построении моделей провести поиск гиперпараметров модели с помощью поиска по сетке с перекрестной проверкой, количество блоков равно 10.

# %%
#Для прогноза модуля упругости при растяжении – Метод RandomForest

from sklearn.model_selection import train_test_split

X = df.drop('Модуль упругости при растяжении, ГПа', axis=1)
y = df['Модуль упругости при растяжении, ГПа']

X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.3, random_state=1)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# %%
random_forest_tuning = RandomForestRegressor (random_state=42)
param_grid = {
    'n_estimators': [100, 200, 500], 
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth': [4, 5, 6, 7, 8],
    'criterion': ['squared_error']
}
GSCV = GridSearchCV(estimator=random_forest_tuning, param_grid=param_grid, cv=10, verbose=2)
GSCV.fit (X_train, y_train)
GSCV.best_params_
# Out:
# Fitting 10 folds for each of 45 candidates, totalling 450 fits
# [CV] END criterion=squared_error, max_depth=4, max_features=auto, n_estimators=100; total time=   0.3s
# [CV] END criterion=squared_error, max_depth=4, max_features=auto, n_estimators=100; total time=   0.3s
# [CV] END criterion=squared_error, max_depth=4, max_features=auto, n_estimators=100; total time=   0.2s
# [CV] END criterion=squared_error, max_depth=4, max_features=auto, n_estimators=100; total time=   0.3s
# [CV] END criterion=squared_error, max_depth=4, max_features=auto, n_estimators=100; total time=   0.3s
# [CV] END criterion=squared_error, max_depth=4, max_features=auto, n_estimators=100; total time=   0.2s
# [CV] END criterion=squared_error, max_depth=4, max_features=auto, n_estimators=100; total time=   0.2s
# [CV] END criterion=squared_error, max_depth=4, max_features=auto, n_estimators=100; total time=   0.2s
# ...

# %%
rf=GSCV.best_estimator_
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=3, n_estimators=500, random_state=42)

# %%
y_pred = rf.predict(X_test)

# %%
y_pred = pd.DataFrame (y_pred, columns = ['yPredict'])

# %%
y_pred
# Out:
#      yPredict
# 0    0.501948
# 1    0.469256
# 2    0.516524
# 3    0.506022
# 4    0.474206
# ..        ...
# 302  0.438941
# 303  0.477582
# 304  0.489070
# 305  0.489305
# 306  0.469754
#
# [307 rows x 1 columns]

# %%
rf.predict(X_test)
# Out:
# array([0.49668296, 0.45678653, 0.51282055, 0.51001856, 0.4758137 ,
#        0.53826552, 0.47901264, 0.48705331, 0.53498714, 0.51386312,
#        0.49277963, 0.49287624, 0.45916575, 0.50578275, 0.51802634,
#        0.48843833, 0.48798036, 0.47794934, 0.49143953, 0.51996057,
#        0.51544348, 0.50705419, 0.49809493, 0.50843355, 0.5024462 ,
#        0.50415988, 0.4822068 , 0.48228662, 0.49318306, 0.52865392,
#        0.46137299, 0.51376307, 0.49475331, 0.47628489, 0.49974921,
#        0.5265898 , 0.50747751, 0.46380203, 0.46696356, 0.51582263,
#        0.49139773, 0.4969292 , 0.45314868, 0.48130646, 0.4859981 ,
#        0.45909388, 0.50723819, 0.44536542, 0.49200916, 0.44549438,
#        0.47292916, 0.49833522, 0.51145585, 0.47185289, 0.49423354,
#        0.51063249, 0.49642472, 0.48942114, 0.52095503, 0.50875918,
#        0.50094435, 0.46620682, 0.54350684, 0.53220517, 0.49176605,
#        0.52786971, 0.51051873, 0.5240084 , 0.49250161, 0.48697469,
# ...

# %%
y_test
# Out:
# Unnamed: 0
# 403    0.174056
# 598    0.828617
# 817    0.512964
# 244    0.253325
# 320    0.689648
#          ...
# 594    0.586788
# 674    0.585272
# 464    0.211007
# 434    0.631181
# 61     0.504358
# Name: Модуль упругости при растяжении, ГПа, Length: 307, dtype: float64

# %%
np.mean(np.abs(y_test-rf.predict(X_test)))
# Out:
# 0.1626041203361939

# %%
plt.figure (figsize = (10, 5))
plt.scatter (y_test, y_pred, color = 'red', label = 'Comparision of Prediction between Actual and Comparision Data ')
plt.legend()
plt.grid()
plt.title('Random Forest Regression')
plt.xlabel('Prediction Data')
plt.ylabel('Actual Data')
plt.show()

# %%
#Для прогноза модуля прочности при растяжении – Метод RandomForest

X1 = df.drop('Прочность при растяжении, МПа', axis=1)
y1 = df['Прочность при растяжении, МПа']

X1_train_val, X1_test, y1_train_val, y1_test = train_test_split(X1, y1, test_size=0.3, random_state=1)
X1_train, X1_val, y1_train, y1_val = train_test_split(X1_train_val, y1_train_val, test_size=0.3, random_state=1)

# %%
y1_pred = rf.predict(X1_train)

# %%
random_forest_tuning = RandomForestRegressor(random_state = 42)
param_grid = {
'n_estimators': [20, 40, 60, 100, 200, 500],
'max_features': ['auto', 'sqrt', 'log2'],
'max_depth' : [3,4,5,6]
}
GSCV = GridSearchCV(estimator=random_forest_tuning, param_grid=param_grid,
cv=10, verbose=0)
GSCV.fit(X1_train, y1_train)
GSCV.best_params_
# Out:
# {'max_depth': 3, 'max_features': 'auto', 'n_estimators': 500}

# %%
rf=GSCV.best_estimator_
rf.fit(X1_train, y1_train)
# Out:
# RandomForestRegressor(max_depth=3, n_estimators=500, random_state=42)

# %%
rf.predict(X1_test)
# Out:
# array([0.461, 0.465, 0.471, 0.476, 0.499, 0.474, 0.47 , 0.479, 0.428,
#        0.445, 0.476, 0.486, 0.479, 0.451, 0.489, 0.483, 0.471, 0.485,
#        0.52 , 0.453, 0.46 , 0.507, 0.505, 0.484, 0.479, 0.514, 0.502,
#        0.51 , 0.525, 0.504, 0.526, 0.434, 0.469, 0.502, 0.523, 0.464,
#        0.485, 0.39 , 0.472, 0.443, 0.485, 0.489, 0.503, 0.511, 0.469,
#        0.504, 0.472, 0.511, 0.465, 0.419, 0.495, 0.467, 0.475, 0.461,
#        0.475, 0.502, 0.468, 0.487, 0.472, 0.509, 0.503, 0.437, 0.469,
#        0.473, 0.47 , 0.523, 0.52 , 0.489, 0.49 , 0.47 , 0.468, 0.437,
#        0.499, 0.48 , 0.471, 0.443, 0.472, 0.475, 0.478, 0.471, 0.471,
#        0.514, 0.48 , 0.558, 0.511, 0.524, 0.505, 0.505, 0.49 , 0.488,
#        0.459, 0.458, 0.474, 0.463, 0.455, 0.494, 0.521, 0.507, 0.554,
#        0.478, 0.499, 0.48 , 0.412, 0.474, 0.531, 0.502, 0.429, 0.496,
#        0.505, 0.511, 0.46 , 0.475, 0.502, 0.49 , 0.509, 0.514, 0.482,
# ...

# %%
y1_pred = rf.predict(X1_test)

# %%
y1_pred = pd.DataFrame (y1_pred, columns = ['yPredict'])

# %%
y1_pred
# Out:
#      yPredict
# 0    0.461238
# 1    0.465448
# 2    0.471135
# 3    0.475531
# 4    0.499256
# ..        ...
# 302  0.503889
# 303  0.510382
# 304  0.496467
# 305  0.471710
# 306  0.474962
#
# [307 rows x 1 columns]

# %%
y1_test
# Out:
# Unnamed: 0
# 403    0.628601
# 598    0.084732
# 817    0.831282
# 244    0.244532
# 320    0.625995
#          ...
# 594    0.721201
# 674    0.328720
# 464    0.133140
# 434    0.253850
# 61     0.511116
# Name: Прочность при растяжении, МПа, Length: 307, dtype: float64

# %%
plt.figure (figsize = (10, 5))
plt.scatter (y1_test, y1_pred, color = 'red', label = 'Comparision of Prediction between Actual and Comparision Data ')
plt.legend()
plt.grid()
plt.title('Random Forest Regression')
plt.xlabel('Prediction Data')
plt.ylabel('Actual Data')
plt.show()

# %%
np.mean(np.abs(y1_test-rf.predict(X1_test)))
# Out:
# 0.16574434196168059

# %% [markdown]
# Метрики оценивания моделей

# %%
from sklearn import metrics

# %%
metrics.r2_score(y1_test, y1_pred)
# Out:
# -0.014342821079014634

# %% [markdown]
# Линейная регрессия

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)

# %%
y_pred
# Out:
# array([0.449, 0.493, 0.521, 0.478, 0.456, 0.49 , 0.507, 0.502, 0.474,
#        0.449, 0.485, 0.53 , 0.455, 0.492, 0.502, 0.463, 0.459, 0.518,
#        0.522, 0.466, 0.518, 0.455, 0.477, 0.461, 0.514, 0.467, 0.472,
#        0.49 , 0.535, 0.499, 0.483, 0.507, 0.48 , 0.515, 0.508, 0.505,
#        0.496, 0.464, 0.485, 0.474, 0.466, 0.487, 0.462, 0.522, 0.483,
#        0.508, 0.49 , 0.554, 0.452, 0.501, 0.497, 0.553, 0.498, 0.531,
#        0.522, 0.481, 0.48 , 0.451, 0.481, 0.529, 0.524, 0.446, 0.466,
#        0.515, 0.497, 0.526, 0.496, 0.512, 0.454, 0.431, 0.507, 0.482,
#        0.505, 0.461, 0.511, 0.501, 0.481, 0.456, 0.481, 0.514, 0.463,
#        0.516, 0.513, 0.45 , 0.501, 0.458, 0.482, 0.521, 0.487, 0.51 ,
#        0.503, 0.512, 0.493, 0.488, 0.498, 0.517, 0.527, 0.509, 0.475,
#        0.452, 0.521, 0.519, 0.516, 0.503, 0.455, 0.524, 0.494, 0.539,
#        0.539, 0.459, 0.462, 0.459, 0.503, 0.494, 0.542, 0.479, 0.466,
# ...

# %%
y_test
# Out:
# array([0.607, 0.388, 0.551, 0.572, 0.652, 0.84 , 0.556, 0.609, 0.655,
#        0.346, 0.768, 0.564, 0.167, 0.45 , 0.585, 0.592, 0.471, 0.893,
#        0.42 , 0.588, 0.254, 0.624, 0.705, 0.759, 0.399, 0.495, 0.713,
#        0.428, 0.239, 0.567, 0.45 , 0.484, 0.339, 0.607, 0.595, 0.466,
#        0.495, 0.498, 0.429, 0.188, 0.218, 0.516, 0.843, 0.533, 0.733,
#        0.611, 0.608, 0.   , 0.178, 0.321, 0.383, 0.429, 0.753, 0.419,
#        0.749, 0.41 , 0.228, 0.036, 0.6  , 0.39 , 0.628, 0.502, 0.52 ,
#        0.245, 0.413, 0.575, 0.729, 0.627, 0.634, 0.518, 0.5  , 0.527,
#        0.628, 0.231, 0.597, 0.58 , 0.458, 0.505, 0.381, 0.474, 0.444,
#        0.535, 0.383, 0.307, 0.691, 0.346, 0.344, 0.229, 0.473, 0.553,
#        0.532, 0.702, 0.309, 0.483, 0.599, 0.539, 0.332, 0.453, 0.307,
#        0.262, 0.412, 0.483, 0.524, 0.656, 0.447, 0.57 , 0.569, 0.52 ,
#        0.792, 0.34 , 0.335, 0.535, 0.306, 0.713, 0.265, 0.499, 0.313,
# ...

# %%
# Calculation of R2 Score
from sklearn.model_selection import cross_val_score
print(cross_val_score(linear_regression, X, y, cv=10, scoring="r2").mean())
# Out:
# -0.016059281069097976

# %%
from sklearn.metrics import mean_squared_error

print(mean_squared_error(y_pred, y_test))
# Out:
# 0.041029912059458926

# %%
print(np.sqrt(mean_squared_error(y_pred, y_test)))
# Out:
# 0.2025584164123005

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X1_train, y1_train)
y1_pred = lr.predict(X1_test)

# %%
y1_pred
# Out:
# array([0.467, 0.452, 0.484, 0.472, 0.514, 0.518, 0.466, 0.514, 0.458,
#        0.475, 0.503, 0.489, 0.509, 0.492, 0.479, 0.493, 0.463, 0.467,
#        0.519, 0.455, 0.463, 0.501, 0.463, 0.521, 0.519, 0.468, 0.521,
#        0.48 , 0.545, 0.5  , 0.51 , 0.536, 0.506, 0.505, 0.472, 0.482,
#        0.476, 0.507, 0.47 , 0.512, 0.521, 0.508, 0.518, 0.489, 0.494,
#        0.478, 0.465, 0.508, 0.519, 0.477, 0.508, 0.467, 0.479, 0.464,
#        0.53 , 0.437, 0.452, 0.491, 0.531, 0.508, 0.489, 0.47 , 0.478,
#        0.505, 0.45 , 0.489, 0.479, 0.489, 0.472, 0.478, 0.504, 0.478,
#        0.46 , 0.46 , 0.529, 0.469, 0.46 , 0.492, 0.49 , 0.492, 0.534,
#        0.537, 0.469, 0.529, 0.522, 0.505, 0.506, 0.501, 0.516, 0.474,
#        0.493, 0.492, 0.518, 0.508, 0.461, 0.521, 0.505, 0.452, 0.512,
#        0.504, 0.515, 0.489, 0.46 , 0.492, 0.469, 0.508, 0.492, 0.511,
#        0.507, 0.472, 0.494, 0.503, 0.479, 0.513, 0.458, 0.466, 0.481,
# ...

# %%
y1_test
# Out:
# array([0.437, 0.69 , 0.857, 0.429, 0.82 , 0.4  , 0.235, 0.57 , 0.602,
#        0.652, 0.785, 0.521, 0.593, 0.423, 0.508, 0.904, 0.838, 0.56 ,
#        0.597, 0.394, 0.254, 0.387, 0.266, 0.533, 0.6  , 0.686, 0.399,
#        0.292, 0.579, 0.393, 0.654, 0.307, 0.295, 0.358, 0.125, 0.22 ,
#        0.132, 0.512, 0.451, 0.573, 0.594, 0.797, 0.596, 0.461, 0.954,
#        0.42 , 0.355, 0.743, 0.3  , 0.382, 0.374, 0.542, 0.475, 0.293,
#        0.606, 0.662, 0.239, 0.398, 0.331, 0.587, 0.857, 0.379, 0.763,
#        0.573, 0.721, 0.612, 0.438, 0.464, 0.307, 0.566, 0.55 , 0.402,
#        0.494, 0.247, 0.401, 0.538, 0.28 , 0.447, 0.153, 0.467, 0.365,
#        0.486, 0.607, 0.388, 0.604, 0.406, 0.23 , 0.508, 0.015, 0.628,
#        0.504, 0.546, 0.541, 0.293, 0.858, 0.429, 0.789, 0.654, 0.51 ,
#        0.69 , 0.762, 0.303, 0.381, 0.268, 0.093, 0.365, 0.616, 0.67 ,
#        0.682, 0.694, 0.271, 0.631, 0.289, 0.471, 0.531, 0.807, 0.571,
# ...

# %%
# Calculation of R2 Score
from sklearn.model_selection import cross_val_score
print(cross_val_score(linear_regression, X1, y1, cv=10, scoring="r2").mean())
# Out:
# -0.03194319218981573

# %%
from sklearn.metrics import mean_squared_error

print(mean_squared_error(y1_pred, y1_test))
# Out:
# 0.03843228331657926

# %%
print(np.sqrt(mean_squared_error(y1_pred, y1_test)))
# Out:
# 0.19604153467206703

# %% [markdown]
# # Нейросеть для рекомендации соотношения матрица-наполнитель

# %% [markdown]
# 2.4.	Написать нейронную сеть, которая будет рекомендовать соотношение матрица.
# Описывается выбранная архитектура нейронной сети и ее результаты.

# %%
X = df.drop('Соотношение матрица-наполнитель', axis=1)
y = df['Соотношение матрица-наполнитель']

# %%
#Число значащих цифр и другие свойства вывода тензоров на печать задаются методом:

np.set_printoptions(precision=3, suppress=True)   # 3 цифры после точки в print

# %%
#Импортируйте TensorFlow:
import tensorflow as tf

from tensorflow import keras 
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2.8.2

# %%
import datetime

# %%
#Задайте тестовую модель
#Обучение и оценка
#Настройка обучения
#После того как модель сконструирована, настройте процесс ее обучения вызовом метода compile::

def build_and_compile_model(norm):
  model = keras.Sequential([
          norm, 
          layers.Dense(128, activation='relu'),
          layers.Dense(64, activation='relu'),
          layers.Dense(1)
  ])

  model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))
  
  return model

# %%
def plot_loss (history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.ylim([0, 0.3])
  plt.xlabel('Эпоха')
  plt.xlabel('MAE[MPG]')
  plt.legend()
  plt.grid(True)

# %%
normalizer = tf.keras.layers.Normalization(axis=-1)

# %%
#Построим простую полносвязную сеть (т.е. многослойный перцептрон):

dnn_model = keras.Sequential([
  layers.Dense(128, activation='relu'), # Добавляем полносвязный слой с 128 узлами
  layers.Dropout(0.6), #помогает предотвратить проблему обучения в глубоких нейронных сетях
  
  layers.Dense(64, activation='relu'),  # Добавляем полносвязный слой с 64 узлами
  layers.Dropout(0.6),
  layers.Dense(1)
])

# Сконфигурируем модель для регрессии со среднеквадратичной ошибкой

dnn_model.compile (loss='mean_squared_error',
  optimizer = tf.keras.optimizers.Adam(0.001))

log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

dnn_model = build_and_compile_model(normalizer)
history = dnn_model.fit(
    X_train,
    y_train,
    validation_data = (X_val, y_val),
    verbose=0, epochs=300,
    callbacks=[tensorboard_callback])

plot_loss(history)
dnn_model.evaluate(X_test, y_test, verbose=0)
# Out:
# 0.20539335906505585
